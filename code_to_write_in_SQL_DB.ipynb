# %%
from pyspark.sql import *

# %%
dbutils.fs.mount(
                    source="wasbs://{container-name}@{storage-name}.blob.core.windows.net/Transformed_data/casendeath",
                    mount_point="/mnt/healthdata",
           extra_configs={"fs.azure.account.key.{storage-name}.blob.core.windows.net":"{Key available in access key of storage account}"}
)
# Out:
# True

# %%
display(dbutils.fs.ls('/mnt/healthdata'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/healthdata/casendeath.csv</td><td>casendeath.csv</td><td>1395224</td><td>1693165937000</td></tr><tr><td>dbfs:/mnt/healthdata/hospitalAdmission_dailydata.csv</td><td>hospitalAdmission_dailydata.csv</td><td>292018</td><td>1693589651000</td></tr><tr><td>dbfs:/mnt/healthdata/hospitalAdmission_weeklydata.csv</td><td>hospitalAdmission_weeklydata.csv</td><td>72354</td><td>1693589765000</td></tr></tbody></table></div>

# %%
##To copy the files from one folder to another
dbutils.fs.cp('dbfs:/mnt/healthdata/hospitalAdmission_weeklydata.csv','dbfs:/mnt/healthdata/casendeath/hospitalAdmission_weeklydata.csv')
# Out:
# True

# %%
filelocation='dbfs:/mnt/healthdata/hospitalAdmission_dailydata.csv'

# %%
s1=spark.read.csv(filelocation,inferSchema=True,header=True)
s1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
sqlconnect='jdbc:sqlserver://server-covid-health.database.windows.net:1433;database=Covid-db;user={server-name}@server-covid-health;password={server-password}@;encrypt=true;trustServerCertificate=false;hostNameInCertificate=*.database.windows.net;loginTimeout=30;'

# %%
s1.write.jdbc(sqlconnect,table='covid_reporting.hospital_admissions_daily',mode='overwrite')

# %%
filelocation1='dbfs:/mnt/healthdata/hospitalAdmission_weeklydata.csv'

# %%
s2=spark.read.csv(filelocation1,inferSchema=True,header=True)
s2.show()
# Out:
# +-------+--------------------+--------------------+----------+------------------+------------------------+----------------------+-------------------+------------------+--------------------+
# |country|country_code_2_digit|country_code_3_digit|population|reported_year_week|reported_week_start_date|reported_week_end_date|new_Occupancy_count|     new_ICU_count|              source|
# +-------+--------------------+--------------------+----------+------------------+------------------------+----------------------+-------------------+------------------+--------------------+
# | France|                  FR|                 FRA|  67012883|          2020-W37|              2020-09-06|            2020-09-12|               NULL| 0.637190911484886|                NULL|
# |Germany|                  DE|                 DEU|  83019213|          2020-W37|              2020-09-06|            2020-09-12|  0.374612079254473|              NULL|TESSy COVID-19, n...|
# ...

# %%
s2.write.jdbc(sqlconnect,table='covid_reporting.hospital_admissions_weekly',mode='overwrite')

# %%
filelocation2='dbfs:/mnt/healthdata/casendeath.csv'

# %%
s3=spark.read.csv(filelocation2,inferSchema=True,header=True)
s3.show()
# Out:
# +--------------------+--------------------+--------------------+----------+-----------+------------+-------------+--------------------+
# |             country|country_code_2_digit|country_code_3_digit|population|cases_count|deaths_count|reported_date|              source|
# +--------------------+--------------------+--------------------+----------+-----------+------------+-------------+--------------------+
# |              Cyprus|                  CY|                 CYP|    875899|          3|           0|   2020-09-11|Epidemic intellig...|
# |            Slovenia|                  SI|                 SVN|   2080908|          0|           0|   2020-05-27|Epidemic intellig...|
# |               Malta|                  MT|                 MLT|    493559|          0|           0|   2020-09-27|Epidemic intellig...|
# |             Romania|                  RO|                 ROU|  19414458|        265|          28|   2020-04-11|Epidemic intellig...|
# ...

# %%
s3.write.jdbc(sqlconnect,table='covid_reporting.cases_and_deaths',mode='overwrite')
